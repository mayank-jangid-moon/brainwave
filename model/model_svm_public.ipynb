# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import svm

# %%
df = pd.read_json("labelled_public.json")

# %%
df
# Out:
#       followersCount  followingCount  isPrivate  isVerified  postsCount  \
# 0             561963             443      False        True         120
# 1             116526              43      False       False          30
# 2             317009             256      False       False         354
# 3             573818             576      False        True         122
# 4             167994             887      False       False         583
# ...              ...             ...        ...         ...         ...
# 1103              67            2110      False       False          22
# 1104            1009             451      False       False           0
# 1105             106            4183      False       False           4
# 1106             102            7211      False       False           4
# 1107              95             917      False       False           6
#
#       username_len  username_num_count  username_ratio  isBio  \
# 0               13                   0        0.000000      1
# 1               10                   0        0.000000      1
# 2               13                   0        0.000000      1
# 3               12                   0        0.000000      1
# 4                9                   0        0.000000      1
# ...            ...                 ...             ...    ...
# 1103            12                   5        0.416667      0
# 1104            14                   4        0.285714      0
# 1105            16                   0        0.000000      1
# 1106            12                   0        0.000000      0
# 1107             9                   3        0.333333      0
#
#       latest_media_comments  latest_media_likes  isLatestPost  label
# 0                       427               60835             1      0
# 1                       170               11862             1      0
# 2                        82                2849             1      0
# 3                      2602              641320             1      0
# 4                       239              253361             1      0
# ...                     ...                 ...           ...    ...
# 1103                      0                   1             1      1
# 1104                      0                   0             0      1
# 1105                      0                   3             1      1
# 1106                      0                   1             1      1
# 1107                      0                   0             1      1
#
# [1108 rows x 13 columns]

# %%
y = df["label"]
X = df.drop("label", axis="columns")

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
clf = svm.SVC(kernel='linear', probability=True, C=1).fit(X_train, y_train)
clf.score(X_test, y_test)

# %%
clf.predict_proba(X_test)

# %%
import joblib

# %%
joblib.dump(clf, "model_svm_public.pkl")
